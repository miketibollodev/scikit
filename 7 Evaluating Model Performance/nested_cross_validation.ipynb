# %% [markdown]
# # Nested Cross-Validation
# When performing hyperparameter tuning, this is a form of machine learning and thus needs to be cross-validated properly.
#
# During the tuning process, the internal cross-validation takes the training set and creates various splits where some of that data is used as training and testing data.

# %%
from sklearn.datasets import load_breast_cancer

data, target = load_breast_cancer(return_X_y=True)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

param_grid = {"C": [0.1, 1, 10], "gamma": [0.01, 0.1]}
model_to_tune = SVC()

search = GridSearchCV(estimator=model_to_tune, param_grid=param_grid, n_jobs=2)
search.fit(data, target)
# Out:
# GridSearchCV(estimator=SVC(), n_jobs=2,
#              param_grid={'C': [0.1, 1, 10], 'gamma': [0.01, 0.1]})

# %%
print(f"The best parameters found are: {search.best_params_}")
# Out:
# The best parameters found are: {'C': 0.1, 'gamma': 0.01}

# %%
print(f"The mean CV score of the best model is: {search.best_score_:.3f}")
# Out:
# The mean CV score of the best model is: 0.627

# %% [markdown]
# It would be naive to assume the mean score can be used to assess the generalization performance of the model. This step has *only* given us the best hyperparameters from the cross-validation it did with the data.
#
# With nested cross-validation, we generate several testing/training splits with the entire dataset for the outer cross-validation. Then, each internal cross-validation is provided the training set of the outer cross-validation and generates its own internal testing/training split.

# %%
from sklearn.model_selection import cross_val_score, KFold

# Declare the inner and outer cross-validation strategies
inner_cv = KFold(n_splits=5, shuffle=True, random_state=0)
outer_cv = KFold(n_splits=3, shuffle=True, random_state=0)

# Inner cross-validation for parameter search
model = GridSearchCV(
    estimator=model_to_tune, param_grid=param_grid, cv=inner_cv, n_jobs=2
)

# Outer cross-validation to compute the testing score
test_score = cross_val_score(model, data, target, cv=outer_cv, n_jobs=2)
print(
    "The mean score using nested cross-validation is: "
    f"{test_score.mean():.3f} ± {test_score.std():.3f}"
)
# Out:
# The mean score using nested cross-validation is: 0.627 ± 0.014

# %%
test_score_not_nested = []
test_score_nested = []

N_TRIALS = 20
for i in range(N_TRIALS):
    # For each trial, we use cross-validation splits on independently
    # randomly shuffled data by passing distinct values to the random_state
    # parameter.
    inner_cv = KFold(n_splits=5, shuffle=True, random_state=i)
    outer_cv = KFold(n_splits=3, shuffle=True, random_state=i)

    # Non_nested parameter search and scoring
    model = GridSearchCV(
        estimator=model_to_tune, param_grid=param_grid, cv=inner_cv, n_jobs=2
    )
    model.fit(data, target)
    test_score_not_nested.append(model.best_score_)

    # Nested CV with parameter optimization
    test_score = cross_val_score(model, data, target, cv=outer_cv, n_jobs=2)
    test_score_nested.append(test_score.mean())

# %%
import pandas as pd

all_scores = {
    "Not nested CV": test_score_not_nested,
    "Nested CV": test_score_nested,
}
all_scores = pd.DataFrame(all_scores)

# %%
import matplotlib.pyplot as plt

color = {"whiskers": "red", "medians": "red", "caps": "red"}
all_scores.plot.box(color=color, vert=False)
plt.xlabel("Accuracy")
_ = plt.title(
    "Comparison of mean accuracy obtained on the test sets with\n"
    "and without nested cross-validation"
)

# %% [markdown]
# As we can see, by hyperparameter tuning and not using nested cross-validation, we have a higher generalization performance (too optimistic).
